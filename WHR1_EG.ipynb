# %% [markdown]
# Step 1: Explore the Data!

# %%
#Import Dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# Import original CSV for cleaning
df1=pd.read_csv("world-happiness-report-2021.csv")

# %%
df1.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %% [markdown]
# Step 2: Clean the the Data!

# %%
df1.dropna()
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df1.dtypes
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# ...

# %%
# Drop Columns that are not needed
df=df1.drop(['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Regional indicator'], axis=1)

# %%
df2=df.set_index('Country name')
df2.head()
# Out:
#               Ladder score  Logged GDP per capita  Social support  \
# Country name
# Finland              7.842                 10.775           0.954
# Denmark              7.620                 10.933           0.954
# Switzerland          7.571                 11.117           0.942
# Iceland              7.554                 10.878           0.983
# Netherlands          7.464                 10.932           0.942
#
#               Healthy life expectancy  Freedom to make life choices  \
# Country name
# Finland                          72.0                         0.949
# Denmark                          72.7                         0.946
# Switzerland                      74.4                         0.919
# Iceland                          73.0                         0.955
# Netherlands                      72.4                         0.913
#
#               Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %% [markdown]
# whatever we think of??

# %% [markdown]
# Step 3: Download data into CSV for Tableau!

# %%
df2.to_csv("world-happiness-report-2021-final.csv")

# %% [markdown]
# Step 4a: Scale/Clean Data for machine learning

# %%
X = df2.iloc[:,1:]
y = df2.iloc[:, 0]
X.head()
# Out:
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                      10.775           0.954                     72.0
# Denmark                      10.933           0.954                     72.7
# Switzerland                  11.117           0.942                     74.4
# Iceland                      10.878           0.983                     73.0
# Netherlands                  10.932           0.942                     72.4
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# Denmark                              0.946       0.030
# Switzerland                          0.919       0.025
# Iceland                              0.955       0.160
# Netherlands                          0.913       0.175
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)

# %%
scaler = Normalizer().fit(X_train) 
LR_X_train = scaler.transform(X_train) 
LR_X_test = scaler.transform(X_test)

# %% [markdown]
# Step 4c: Linear Regressions

# %%
reg = LinearRegression().fit(LR_X_train, y_train)
y_pred = reg.predict(LR_X_test)
r2 = r2_score(y_test, y_pred)
print("Standard linear regression R2 = ", r2, "\n")
coef = reg.coef_
print("Standard linear regression coefficients :")
i = 0; 
for col in X.columns:
  print(col, ":", coef[i])
  i = i + 1
# Out:
# Standard linear regression R2 =  0.9914092136125872
#
# Standard linear regression coefficients :
# Logged GDP per capita : 1208.5714259028696
# Social support : -1623.215210283803
# Healthy life expectancy : 227.90066982643353
# Freedom to make life choices : 222.9966783836703
# Generosity : -2317.5888731764353
# Perceptions of corruption : -1662.1518244186673
# Ladder score in Dystopia : -4325.578382399779
# Explained by: Log GDP per capita : -3327.589917418337
# Explained by: Social support : 789.6117513400097
# Explained by: Healthy life expectancy : -2488.8144670750175
# Explained by: Freedom to make life choices : -128.65635572941446
# Explained by: Generosity : 3617.8288496542377
# Explained by: Perceptions of corruption : -2506.3453616643524
# Dystopia + residual : 70.7379940791872

# %% [markdown]
# Step 4d: Decision tree

# %%
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.5389770277873656

# %% [markdown]
# Step 4e:Random Forest

# %%
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
y_pred = forest.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8523732674780308

# %% [markdown]
# Step 5: Analysis!
